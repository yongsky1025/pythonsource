# %% [markdown]
# ### 데이터베이스 연동
# - 내장 DB 제공 : sqlite(RDBMS)
# - 외부 DB 사용 가능 : mysql, mongo db
# - 라이브러리 설치 : pymysql

# %%
# mysql
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\source\pythonsource\.venv\Lib\site-packages (1.1.2)

# %% [markdown]
# ### 연결
# - connect() : db 서버 연동
# - cursor : DB 와 연결 후 접근할 수 있는 객체

# %%
import pymysql

# %%
conn = pymysql.connect(
    host="localhost", 
    user="javadb", 
    password="12345", 
    database='springdb', 
    charset="utf8mb4"
    )

# %% [markdown]
# #### 조회
# - fetchall()
# - fetchone()
# - fetchmany()

# %%
with conn.cursor() as cursor:
    sql = "select * from booktbl"
    cursor.execute(sql)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (36000, 2, '천인국1', None, 'A1010101', '파워 자바1')
# (36000, 3, '천인국2', None, 'A1010102', '파워 자바2')
# (30000, 4, '천인국3', '', 'A1010103', '파워 자바3')
# (36000, 5, '천인국4', None, 'A1010104', '파워 자바4')
# (12000, 6, '천인국5', '', 'A1010105', '파워 자바5')
# (36000, 7, '천인국6', None, 'A1010106', '파워 자바6')
# (36000, 8, '천인국7', None, 'A1010107', '파워 자바7')
# (36000, 9, '천인국8', None, 'A1010108', '파워 자바8')
# (15000, 12, '천인국', 'ㅁㄴㅇㄴㅁㅇ', 'A101010', '파워 자바')
# (36000, 15, '천인국1', None, '3808c0c3-d58e-11f0-bf9a-7c57580ed576', '파워 자바1')
# (36000, 16, '천인국2', None, '3808cf0b-d58e-11f0-bf9a-7c57580ed576', '파워 자바2')
# (30000, 17, '천인국3', '', '3808d8a8-d58e-11f0-bf9a-7c57580ed576', '파워 자바3')
# (36000, 18, '천인국4', None, '3808d8e8-d58e-11f0-bf9a-7c57580ed576', '파워 자바4')
# (12000, 19, '천인국5', '', '3808d907-d58e-11f0-bf9a-7c57580ed576', '파워 자바5')
# (36000, 20, '천인국6', None, '3808d91c-d58e-11f0-bf9a-7c57580ed576', '파워 자바6')
# (36000, 21, '천인국7', None, '3808d931-d58e-11f0-bf9a-7c57580ed576', '파워 자바7')
# (36000, 22, '천인국8', None, '3808d945-d58e-11f0-bf9a-7c57580ed576', '파워 자바8')
# (15000, 23, '천인국', 'ㅁㄴㅇㄴㅁㅇ', '3808d956-d58e-11f0-bf9a-7c57580ed576', '파워 자바')
# (36000, 30, '천인국1', None, '69aa0233-d58e-11f0-bf9a-7c57580ed576', '파워 자바1')
# (36000, 31, '천인국2', None, '69aa029d-d58e-11f0-bf9a-7c57580ed576', '파워 자바2')
# (30000, 32, '천인국3', '', '69aa02b8-d58e-11f0-bf9a-7c57580ed576', '파워 자바3')
# (36000, 33, '천인국4', None, '69aa02cd-d58e-11f0-bf9a-7c57580ed576', '파워 자바4')
# (12000, 34, '천인국5', '', '69aa02df-d58e-11f0-bf9a-7c57580ed576', '파워 자바5')
# (36000, 35, '천인국6', None, '69aa02f1-d58e-11f0-bf9a-7c57580ed576', '파워 자바6')
# (36000, 36, '천인국7', None, '69aa0301-d58e-11f0-bf9a-7c57580ed576', '파워 자바7')
# (36000, 37, '천인국8', None, '69aa030f-d58e-11f0-bf9a-7c57580ed576', '파워 자바8')
# (15000, 38, '천인국', 'ㅁㄴㅇㄴㅁㅇ', '69aa031e-d58e-11f0-bf9a-7c57580ed576', '파워 자바')
# (36000, 39, '천인국1', None, '69aa0331-d58e-11f0-bf9a-7c57580ed576', '파워 자바1')
# (36000, 40, '천인국2', None, '69aa0340-d58e-11f0-bf9a-7c57580ed576', '파워 자바2')
# (30000, 41, '천인국3', '', '69aa034e-d58e-11f0-bf9a-7c57580ed576', '파워 자바3')
# (36000, 42, '천인국4', None, '69aa0360-d58e-11f0-bf9a-7c57580ed576', '파워 자바4')
# (12000, 43, '천인국5', '', '69aa036e-d58e-11f0-bf9a-7c57580ed576', '파워 자바5')
# (36000, 44, '천인국6', None, '69aa037b-d58e-11f0-bf9a-7c57580ed576', '파워 자바6')
# (36000, 45, '천인국7', None, '69aa0388-d58e-11f0-bf9a-7c57580ed576', '파워 자바7')
# (36000, 46, '천인국8', None, '69aa0395-d58e-11f0-bf9a-7c57580ed576', '파워 자바8')
# (15000, 47, '천인국', 'ㅁㄴㅇㄴㅁㅇ', '69aa03a1-d58e-11f0-bf9a-7c57580ed576', '파워 자바')
# (36000, 61, '천인국1', None, '69bac388-d58e-11f0-bf9a-7c57580ed576', '파워 자바1')
# (36000, 62, '천인국2', None, '69bac3e2-d58e-11f0-bf9a-7c57580ed576', '파워 자바2')
# (30000, 63, '천인국3', '', '69bac3fc-d58e-11f0-bf9a-7c57580ed576', '파워 자바3')
# (36000, 64, '천인국4', None, '69bac411-d58e-11f0-bf9a-7c57580ed576', '파워 자바4')
# (12000, 65, '천인국5', '', '69bac425-d58e-11f0-bf9a-7c57580ed576', '파워 자바5')
# (36000, 66, '천인국6', None, '69bac434-d58e-11f0-bf9a-7c57580ed576', '파워 자바6')
# (36000, 67, '천인국7', None, '69bac443-d58e-11f0-bf9a-7c57580ed576', '파워 자바7')
# (36000, 68, '천인국8', None, '69bac454-d58e-11f0-bf9a-7c57580ed576', '파워 자바8')
# (15000,
d62d-11f0-99bb-7c57580ed576', '파워 자바6')
# (36000, 361, '천인국7', None, 'c5d5f1c8-d62d-11f0-99bb-7c57580ed576', '파워 자바7')
# (36000, 362, '천인국8', None, 'c5d5f1e3-d62d-11f0-99bb-7c57580ed576', '파워 자바8')
# (15000, 363, '천인국', None, 'c5d5f202-d62d-11f0-99bb-7c57580ed576', '파워 자바')
# (36000, 364, '천인국1', None, 'c5d5f21f-d62d-11f0-99bb-7c57580ed576', '파워 자바1')
# (36000, 365, '천인국2', None, 'c5d5f23d-d62d-11f0-99bb-7c57580ed576', '파워 자바2')
# (30000, 366, '천인국3', None, 'c5d5f25b-d62d-11f0-99bb-7c57580ed576', '파워 자바3')
# (36000, 367, '천인국4', None, 'c5d5f277-d62d-11f0-99bb-7c57580ed576', '파워 자바4')
# (12000, 368, '천인국5', None, 'c5d5f291-d62d-11f0-99bb-7c57580ed576', '파워 자바5')
# (36000, 369, '천인국6', None, 'c5d5f2ab-d62d-11f0-99bb-7c57580ed576', '파워 자바6')
# (36000, 370, '천인국7', None, 'c5d5f2c4-d62d-11f0-99bb-7c57580ed576', '파워 자바7')
# (36000, 371, '천인국8', None, 'c5d5f2dd-d62d-11f0-99bb-7c57580ed576', '파워 자바8')
# (15000, 372, '천인국', None, 'c5d5f2f8-d62d-11f0-99bb-7c57580ed576', '파워 자바')
# (36000, 373, '천인국1', None, 'c5d5f310-d62d-11f0-99bb-7c57580ed576', '파워 자바1')
# (36000, 374, '천인국2', None, 'c5d5f328-d62d-11f0-99bb-7c57580ed576', '파워 자바2')
# (30000, 375, '천인국3', None, 'c5d5f345-d62d-11f0-99bb-7c57580ed576', '파워 자바3')
# (36000, 376, '천인국4', None, 'c5d5f362-d62d-11f0-99bb-7c57580ed576', '파워 자바4')
# (12000, 377, '천인국5', None, 'c5d5f37d-d62d-11f0-99bb-7c57580ed576', '파워 자바5')
# (36000, 378, '천인국6', None, 'c5d5f39a-d62d-11f0-99bb-7c57580ed576', '파워 자바6')
# (36000, 379, '천인국7', None, 'c5d5f3d3-d62d-11f0-99bb-7c57580ed576', '파워 자바7')
# (36000, 380, '천인국8', None, 'c5d5f3f2-d62d-11f0-99bb-7c57580ed576', '파워 자바8')
# (30000, 384, '천인국3', None, 'c5d5f47e-d62d-11f0-99bb-7c57580ed576', '파워 자바3')
# (36000, 385, '천인국4', None, 'c5d5f496-d62d-11f0-99bb-7c57580ed576', '파워 자바4')
# (12000, 386, '천인국5', None, 'c5d5f4b0-d62d-11f0-99bb-7c57580ed576', '파워 자바5')
# (36000, 387, '천인국6', None, 'c5d5f4cf-d62d-11f0-99bb-7c57580ed576', '파워 자바6')
# (36000, 388, '천인국7', None, 'c5d5f4ed-d62d-11f0-99bb-7c57580ed576', '파워 자바7')
# (36000, 389, '천인국8', None, 'c5d5f507-d62d-11f0-99bb-7c57580ed576', '파워 자바8')
# (15000, 390, '천인국', None, 'c5d5f523-d62d-11f0-99bb-7c57580ed576', '파워 자바')
# (36000, 391, '천인국1', None, 'c5d5f544-d62d-11f0-99bb-7c57580ed576', '파워 자바1')
# (36000, 392, '천인국2', None, 'c5d5f560-d62d-11f0-99bb-7c57580ed576', '파워 자바2')
# (30000, 393, '천인국3', None, 'c5d5f57f-d62d-11f0-99bb-7c57580ed576', '파워 자바3')
# (36000, 394, '천인국4', None, 'c5d5f599-d62d-11f0-99bb-7c57580ed576', '파워 자바4')
# (12000, 395, '천인국5', None, 'c5d5f5b5-d62d-11f0-99bb-7c57580ed576', '파워 자바5')
# (36000, 396, '천인국6', None, 'c5d5f5cd-d62d-11f0-99bb-7c57580ed576', '파워 자바6')
# (36000, 397, '천인국7', None, 'c5d5f5e4-d62d-11f0-99bb-7c57580ed576', '파워 자바7')
# (36000, 398, '천인국8', None, 'c5d5f5fc-d62d-11f0-99bb-7c57580ed576', '파워 자바8')
# (15000, 399, '천인국', None, 'c5d5f61b-d62d-11f0-99bb-7c57580ed576', '파워 자바')
# (36000, 400, '천인국0', 'ㅎㅇㅎㅇ', 'c5d5f639-d62d-11f0-99bb-7c57580ed576', '파워 자바0')
# (123123, 511, 'ㅎㅇㅎㅇ', 'ㅎㅇㅎㅇ', 'ㅎㅇㅎ', 'ㅎㅇㅎㅇ')
# (3333, 512, '3333', '3333', 'ㅁㄴㅇ', '123')

# %%
with conn.cursor() as cursor:
    sql = "select * from booktbl"
    cursor.execute(sql)
    rows = cursor.fetchmany(size=10)
    for row in rows:
        print(row)
# Out:
# (36000, 2, '천인국1', None, 'A1010101', '파워 자바1')
# (36000, 3, '천인국2', None, 'A1010102', '파워 자바2')
# (30000, 4, '천인국3', '', 'A1010103', '파워 자바3')
# (36000, 5, '천인국4', None, 'A1010104', '파워 자바4')
# (12000, 6, '천인국5', '', 'A1010105', '파워 자바5')
# (36000, 7, '천인국6', None, 'A1010106', '파워 자바6')
# (36000, 8, '천인국7', None, 'A1010107', '파워 자바7')
# (36000, 9, '천인국8', None, 'A1010108', '파워 자바8')
# (15000, 12, '천인국', 'ㅁㄴㅇㄴㅁㅇ', 'A101010', '파워 자바')
# (36000, 15, '천인국1', None, '3808c0c3-d58e-11f0-bf9a-7c57580ed576', '파워 자바1')

# %%
with conn.cursor() as cursor:
    sql = "select * from booktbl"
    cursor.execute(sql)
    rows = cursor.fetchone()
    print(rows)
# Out:
# (36000, 2, '천인국1', None, 'A1010101', '파워 자바1')

# %% [markdown]
# #### 테이블 생성

# %%
with conn.cursor() as cursor:
    sql = "create table if not exists users(id int primary key auto_increment, name varchar(30),"\
    "email varchar(100), phone varchar(20), website varchar(50), regdate date)"
    cursor.execute(sql)

# %% [markdown]
# #### 삽입

# %%
# import datetime

# datetime.datetime.now()

from datetime import datetime
now = datetime.now()
print(now)
today = now.strftime("%Y/%m/%d")
# Out:
# 2026-02-09 17:01:36.559403

# %%
# 데이터 삽입 시 튜플 형태

with conn.cursor() as cursor:
    sql = "insert into users(name, email, phone, website, regdate) values(%s,%s,%s,%s,%s)"
    cursor.execute(sql,('user1', 'user1@gmail.com','010-1234-1234','http://user1.com',today))

conn.commit()

# %% [markdown]
# #### 조회

# %%
with conn.cursor() as cursor:
    # sql = "select * from users"
    sql = "select * from users where id=3" # 특정 id값
    cursor.execute(sql)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (3, 'user3', 'user3@gmail.com', '010-1234-1234', 'http://user3.com', datetime.date(2026, 2, 9))

# %%
with conn.cursor() as cursor:

    users = (
        ('user2','user2@gmail.com','010-1234-1234','http://user2.com',today),
        ('user3','user3@gmail.com','010-1234-1234','http://user3.com',today),
        ('user4','user4@gmail.com','010-1234-1234','http://user4.com',today),
        ('user5','user5@gmail.com','010-1234-1234','http://user5.com',today)
    )


    sql = "insert into users(name, email, phone, website, regdate) values(%s,%s,%s,%s,%s)"
    cursor.executemany(sql,users)

conn.commit()

# %%
with conn.cursor() as cursor:
    sql = "select * from users where id=%s"
    cursor.execute(sql,5)  # %s에 들어갈 특정 id값
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (5, 'user5', 'user5@gmail.com', '010-1234-1234', 'http://user5.com', datetime.date(2026, 2, 9))

# %%
# 2개 불러올때

with conn.cursor() as cursor:
    sql = "select * from users where id in (%s,%s)"
    cursor.execute(sql,(3,5))
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (3, 'user3', 'user3@gmail.com', '010-1234-1234', 'http://user3.com', datetime.date(2026, 2, 9))
# (5, 'user5', 'user5@gmail.com', '010-1234-1234', 'http://user5.com', datetime.date(2026, 2, 9))

# %% [markdown]
# #### 업데이트

# %%
with conn.cursor() as cursor:
    sql = "update users set name=%s where id=%s" 
    cursor.execute(sql,('change2',2))

conn.commit()

# %% [markdown]
# #### 삭제

# %%
with conn.cursor() as cursor:
    sql = "delete from users where id=%s" 
    cursor.execute(sql,5)

conn.commit()
